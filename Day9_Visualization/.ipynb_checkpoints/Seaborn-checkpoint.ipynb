# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv("fifa.csv",index_col='Date',parse_dates=True)

# %%
fifa.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# # LinePlot

# %%
sns.lineplot(data=fifa)

# %%
#sns.lineplot(data=fifa,sizes=(5.25,10.5)) #Sizes is not making any differences
plt.figure(figsize=(16,6))
sns.lineplot(data=fifa)

# %%
versi=pd.read_csv("iris_versicolor.csv")

# %%
versi=versi.set_index("Id")

# %%
versi.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 51                7.0               3.2                4.7               1.4
# 52                6.4               3.2                4.5               1.5
# 53                6.9               3.1                4.9               1.5
# 54                5.5               2.3                4.0               1.3
# 55                6.5               2.8                4.6               1.5
#
#             Species
# Id
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor
