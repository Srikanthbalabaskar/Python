# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data",sep=' ',)

# %%
data.head()
# Out:
#    Yr  Mo   Dy  Unnamed: 3  Unnamed: 4    RPT  Unnamed: 6  Unnamed: 7    VAL  \
# 0  61 NaN  1.0         NaN         1.0  15.04       14.96       13.17    NaN
# 1  61 NaN  1.0         NaN         2.0  14.71         NaN         NaN    NaN
# 2  61 NaN  1.0         NaN         3.0  18.50       16.88       12.33  10.13
# 3  61 NaN  1.0         NaN         4.0  10.58         NaN        6.63  11.75
# 4  61 NaN  1.0         NaN         5.0  13.33       13.25       11.42    NaN
#
#    Unnamed: 9  ...  MUL  Unnamed: 30  Unnamed: 31  CLO  Unnamed: 33  \
# 0        9.29  ...  NaN          NaN          NaN  NaN          NaN
# 1       10.83  ...  NaN          NaN          NaN  NaN          NaN
# 2       11.17  ...  NaN          NaN          NaN  NaN          NaN
# 3         NaN  ...  NaN          NaN          NaN  NaN          NaN
# 4        6.17  ...  NaN          NaN          NaN  NaN          NaN
#
#    Unnamed: 34  BEL  Unnamed: 36  Unnamed: 37  MAL
# ...

# %%
data=pd.read_fwf("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data")

# %%
data.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         Yr         Mo         Dy        RPT        VAL        ROS
# 1         61          1          1      15.04      14.96      13.17
# 2         61          1          2      14.71        NaN      10.83
# 3         61          1          3      18.50      16.88      12.33
# 4         61          1          4      10.58       6.63      11.75
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        KIL        SHA        BIR        DUB         CLA         MUL
# 1       9.29        NaN       9.87      13.67       10.25       10.83
# 2       6.50      12.62       7.67      11.50       10.04        9.79
# 3      10.13      11.17       6.17      11.25         NaN        8.50
# 4       4.58       4.54       2.88       8.63        1.79        5.83
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0         CLO         BEL         MAL
# 1       12.58       18.50       15.04
# ...

# %%
data.iloc[0]
# Out:
# Unnamed: 0      Yr
# Unnamed: 1      Mo
# Unnamed: 2      Dy
# Unnamed: 3     RPT
# Unnamed: 4     VAL
# Unnamed: 5     ROS
# Unnamed: 6     KIL
# Unnamed: 7     SHA
# Unnamed: 8     BIR
# Unnamed: 9     DUB
# Unnamed: 10    CLA
# Unnamed: 11    MUL
# Unnamed: 12    CLO
# Unnamed: 13    BEL
# Unnamed: 14    MAL
# Name: 0, dtype: object

# %%
#changing the columns to 1st row

data.columns=data.iloc[0]
data=data.iloc[1:]   # to again remove the columns from 1st row
data.head()
# Out:
# 0  Yr Mo Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 1  61  1  1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 2  61  1  2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 3  61  1  3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 4  61  1  4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 5  61  1  5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
# 0    CLO    BEL    MAL
# 1  12.58  18.50  15.04
# 2   9.67  17.54  13.83
# 3   7.67  12.75  12.71
# 4   5.88   5.46  10.88
# 5  10.34  12.92  11.83

# %%
data=data.rename(columns={'Yr':'Year', 'Mo':'Month','Dy':"Day"})
data.head()
# Out:
# 0 Year Month Day    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA  \
# 1   61     1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25
# 2   61     1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04
# 3   61     1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN
# 4   61     1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79
# 5   61     1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54
#
# 0    MUL    CLO    BEL    MAL
# 1  10.83  12.58  18.50  15.04
# 2   9.79   9.67  17.54  13.83
# 3   8.50   7.67  12.75  12.71
# 4   5.83   5.88   5.46  10.88
# 5  10.92  10.34  12.92  11.83

# %%
data.dtypes
# Out:
# 0
# Year     object
# Month    object
# Day      object
# RPT      object
# VAL      object
# ROS      object
# KIL      object
# SHA      object
# BIR      object
# DUB      object
# CLA      object
# MUL      object
# CLO      object
# BEL      object
# MAL      object
# dtype: object

# %%
data['Year']=pd.to_numeric(data['Year']) +1900
data.head()
# Out:
# 0  Year Month Day    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA  \
# 1  1961     1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25
# 2  1961     1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04
# 3  1961     1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN
# 4  1961     1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79
# 5  1961     1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54
#
# 0    MUL    CLO    BEL    MAL
# 1  10.83  12.58  18.50  15.04
# 2   9.79   9.67  17.54  13.83
# 3   8.50   7.67  12.75  12.71
# 4   5.83   5.88   5.46  10.88
# 5  10.92  10.34  12.92  11.83

# %%
data['Date']=pd.to_datetime(data[['Year','Month','Day']])

data.set_index('Date',inplace=True)
data.head()
data.drop(columns={'Year','Month','Day'},inplace=True)#another to do it is del data['Year']

# %%
data.head()
# Out:
# 0             RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
# 0             CLO    BEL    MAL
# Date
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %%
data.dtypes
# Out:
# 0
# RPT    object
# VAL    object
# ROS    object
# KIL    object
# SHA    object
# BIR    object
# DUB    object
# CLA    object
# MUL    object
# CLO    object
# BEL    object
# MAL    object
# dtype: object

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
data['Date_Dup']=data.index
data.head()
# Out:
# 0             RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
# 0             CLO    BEL    MAL   Date_Dup
# Date
# 1961-01-01  12.58  18.50  15.04 1961-01-01
# 1961-01-02   9.67  17.54  13.83 1961-01-02
# 1961-01-03   7.67  12.75  12.71 1961-01-03
# 1961-01-04   5.88   5.46  10.88 1961-01-04
# 1961-01-05  10.34  12.92  11.83 1961-01-05

# %%
data['Date_Dup'].dt.year == '2061'
# Out:
# C:\Users\srika\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Date
# 1961-01-01    False
# 1961-01-02    False
# 1961-01-03    False
# 1961-01-04    False
# 1961-01-05    False
#               ...
# 1978-12-27    False
# 1978-12-28    False
# 1978-12-29    False
# 1978-12-30    False
# 1978-12-31    False
# Name: Date_Dup, Length: 6574, dtype: bool

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.index
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Date', length=6574, freq=None)

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isna().sum()
# Out:
# 0
# RPT         6
# VAL         3
# ROS         2
# KIL         5
# SHA         2
# BIR         0
# DUB         3
# CLA         2
# MUL         3
# CLO         1
# BEL         0
# MAL         4
# Date_Dup    0
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
#Overall Data
data.count()
sum(data.count())  #Sum of all Values
# Out:
# 85431

# %%
(data.isna().sum()).sum()   #Sum of NA Values alone
# Out:
# 31

# %%
print('Non-Missing Values=',sum(data.count())-(data.isna().sum()).sum() )
# Out:
# Non-Missing Values= 85400

# %%
data.dropna(inplace=True)

# %%
del data['Date_Dup']

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
#Change all the data types to float
datanew=data.apply(lambda x: x.astype('float64'),axis=1)

# %%
datanew.dtypes
# Out:
# 0
# RPT    float64
# VAL    float64
# ROS    float64
# KIL    float64
# SHA    float64
# BIR    float64
# DUB    float64
# CLA    float64
# MUL    float64
# CLO    float64
# BEL    float64
# MAL    float64
# dtype: object

# %%
(datanew.apply(lambda x:x.mean(),axis=0)).mean()
# Out:
# 10.222465245951712

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
datanew.describe()
# Out:
# 0              RPT          VAL          ROS          KIL          SHA  \
# count  6546.000000  6546.000000  6546.000000  6546.000000  6546.000000
# mean     12.359979    10.640267    11.656396     6.298587    10.448923
# std       5.618805     5.268695     5.007805     3.600942     4.933988
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     7.970000     3.580000     6.750000
# 50%      11.710000    10.130000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.380000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
# 0              BIR          DUB          CLA          MUL          CLO  \
# count  6546.000000  6546.000000  6546.000000  6546.000000  6546.000000
# mean      7.085066     9.793006     8.486601     8.490257     8.696705
# std       3.967735     4.978030     4.498299     4.165947     4.500488
# ...

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
mini=datanew.min(axis=1)
mini
# Out:
# Date
# 1961-01-04    1.79
# 1961-01-05    6.17
# 1961-01-06    4.42
# 1961-01-07    4.96
# 1961-01-08    5.91
#               ...
# 1978-12-27    8.08
# 1978-12-28    5.00
# 1978-12-29    8.71
# 1978-12-30    9.13
# 1978-12-31    9.59
# Length: 6546, dtype: float64

# %%
maxi=datanew.max(axis=1)
maxi
# Out:
# Date
# 1961-01-04    11.75
# 1961-01-05    13.33
# 1961-01-06    13.21
# 1961-01-07    14.29
# 1961-01-08    16.62
#               ...
# 1978-12-27    40.08
# 1978-12-28    41.46
# 1978-12-29    29.58
# 1978-12-30    28.79
# 1978-12-31    27.29
# Length: 6546, dtype: float64

# %%
maxi=datanew.max(axis=1)
maxi
# Out:
# Date
# 1961-01-04    11.75
# 1961-01-05    13.33
# 1961-01-06    13.21
# 1961-01-07    14.29
# 1961-01-08    16.62
#               ...
# 1978-12-27    40.08
# 1978-12-28    41.46
# 1978-12-29    29.58
# 1978-12-30    28.79
# 1978-12-31    27.29
# Length: 6546, dtype: float64

# %%
aver= datanew.mean(axis=1)
aver
# Out:
# Date
# 1961-01-04     6.619167
# 1961-01-05    10.630000
# 1961-01-06     8.240000
# 1961-01-07    10.385000
# 1961-01-08    10.487500
#                 ...
# 1978-12-27    16.708333
# 1978-12-28    15.150000
# 1978-12-29    14.890000
# 1978-12-30    15.367500
# 1978-12-31    15.402500
# Length: 6546, dtype: float64

# %%
standard=datanew.std(axis=1)
standard
# Out:
# Date
# 1961-01-04    3.198126
# 1961-01-05    2.445356
# 1961-01-06    2.998063
# 1961-01-07    3.072114
# 1961-01-08    3.547237
#                 ...
# 1978-12-27    7.868076
# 1978-12-28    9.687857
# 1978-12-29    5.756836
# 1978-12-30    5.540437
# 1978-12-31    5.702483
# Length: 6546, dtype: float64

# %%
mini_series=pd.Series(mini,name='Min')
maxi_series=pd.Series(maxi,name='Max')
mean_Series=pd.Series(aver,name='Mean')
std_Series=pd.Series(standard,name='Std')

# %%
day_stats=pd.concat([mini_series,maxi_series,mean_Series,std_Series],axis=1)
day_stats
# Out:
#              Min    Max       Mean       Std
# Date
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# 1961-01-06  4.42  13.21   8.240000  2.998063
# 1961-01-07  4.96  14.29  10.385000  3.072114
# 1961-01-08  5.91  16.62  10.487500  3.547237
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6546 rows x 4 columns]

# %%
#Just converting into DataFrame wont work out.. Concat is the correct way
day=pd.DataFrame(data=[mini_series,maxi_series])

# %%
day
# Out:
# Date  1961-01-04  1961-01-05  1961-01-06  1961-01-07  1961-01-08  1961-01-09  \
# Min         1.79        6.17        4.42        4.96        5.91        4.75
# Max        11.75       13.33       13.21       14.29       16.62       15.37
#
# Date  1961-01-10  1961-01-11  1961-01-12  1961-01-13  ...  1978-12-22  \
# Min         6.54        2.79        9.46        0.58  ...        2.46
# Max        19.50       20.71       19.75        9.92  ...       13.08
#
# Date  1978-12-23  1978-12-24  1978-12-25  1978-12-26  1978-12-27  1978-12-28  \
# Min         9.50        4.79        0.75        1.96        8.08        5.00
# Max        22.21       31.71       13.96       13.83       40.08       41.46
#
# Date  1978-12-29  1978-12-30  1978-12-31
# Min         8.71        9.13        9.59
# Max        29.58       28.79       27.29
#
# [2 rows x 6546 columns]

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
datanew['Month']=datanew.index.month
datanew.head()
# Out:
# 0             RPT    VAL    ROS   KIL    SHA   BIR    DUB   CLA    MUL    CLO  \
# Date
# 1961-01-04  10.58   6.63  11.75  4.58   4.54  2.88   8.63  1.79   5.83   5.88
# 1961-01-05  13.33  13.25  11.42  6.17  10.71  8.21  11.92  6.54  10.92  10.34
# 1961-01-06  13.21   8.12   9.96  6.67   5.37  4.50  10.67  4.42   7.17   7.50
# 1961-01-07  13.50  14.29   9.50  4.96  12.29  8.33   9.17  9.29   7.58   7.96
# 1961-01-08  10.96   9.75   7.62  5.91   9.62  7.29  14.29  7.62   9.25  10.46
#
# 0             BEL    MAL  Month
# Date
# 1961-01-04   5.46  10.88      1
# 1961-01-05  12.92  11.83      1
# 1961-01-06   8.12  13.17      1
# 1961-01-07  13.96  13.79      1
# 1961-01-08  16.62  16.46      1

# %%
dataJan=datanew.query('Month==1')
dataJanmean=dataJan.mean(axis=0)
dataJanmean
# Out:
# 0
# RPT      14.831609
# VAL      12.885389
# ROS      13.276275
# KIL       7.152477
# SHA      11.644467
# BIR       8.030561
# DUB      11.788336
# CLA       9.486962
# MUL       9.511501
# CLO      10.024069
# BEL      14.527848
# MAL      18.041826
# Month     1.000000
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
datanew['Year']=datanew.index.year
datanew.head()
# Out:
# 0             RPT    VAL    ROS   KIL    SHA   BIR    DUB   CLA    MUL    CLO  \
# Date
# 1961-01-04  10.58   6.63  11.75  4.58   4.54  2.88   8.63  1.79   5.83   5.88
# 1961-01-05  13.33  13.25  11.42  6.17  10.71  8.21  11.92  6.54  10.92  10.34
# 1961-01-06  13.21   8.12   9.96  6.67   5.37  4.50  10.67  4.42   7.17   7.50
# 1961-01-07  13.50  14.29   9.50  4.96  12.29  8.33   9.17  9.29   7.58   7.96
# 1961-01-08  10.96   9.75   7.62  5.91   9.62  7.29  14.29  7.62   9.25  10.46
#
# 0             BEL    MAL  Month  Year
# Date
# 1961-01-04   5.46  10.88      1  1961
# 1961-01-05  12.92  11.83      1  1961
# 1961-01-06   8.12  13.17      1  1961
# 1961-01-07  13.96  13.79      1  1961
# 1961-01-08  16.62  16.46      1  1961

# %%
datanew.groupby('Year').sum()
# Out:
# 0         RPT      VAL      ROS      KIL      SHA      BIR      DUB      CLA  \
# Year
# 1961  4150.58  3470.45  3836.17  2327.79  3652.53  2589.83  3275.31  2952.87
# 1962  4443.47  3674.61  4240.60  2521.09  3870.60  2684.35  3997.61  3196.39
# 1963  4676.91  3955.50  4577.52  2675.47  4279.30  3078.67  4042.63  3772.84
# 1964  4525.10  3996.78  4430.20  2484.33  4192.34  2770.94  3754.85  3465.05
# 1965  4544.75  4042.57  4324.80  2503.34  4024.05  2729.51  3875.83  3241.17
# 1966  4913.62  4218.38  4387.53  2681.19  4308.84  2844.69  3861.63  3224.81
# 1967  4649.06  4011.71  4284.88  2607.35  4245.22  2689.38  3887.99  3403.85
# 1968  4331.84  3831.36  4175.97  2370.83  3938.44  2220.64  3242.46  3021.52
# Date
# 1961-01-04   5.46  10.88      1  1961         1     1961     1961-1
# 1961-01-05  12.92  11.83      1  1961         1     1961     1961-1
# 1961-01-06   8.12  13.17      1  1961         1     1961     1961-1
# 1961-01-07  13.96  13.79      1  1961         1     1961     1961-1
# 1961-01-08  16.62  16.46      1  1961         1     1961     1961-1

# %%
datanew1.groupby('Year-Month').mean()
# Out:
# 0                 RPT        VAL        ROS       KIL        SHA        BIR  \
# Year-Month
# 1961-1      14.506154  11.225385  12.960385  6.840000  10.509231   8.174231
# 1961-10     13.871379  10.635517  12.123103  8.020345  11.528966   8.150000
# 1961-11     11.056552   8.542759  12.106552  6.183793   9.133793   6.249310
# 1961-12     14.973548  11.903871  13.980323  7.073871  11.323548   8.302258
# 1961-2      16.401923  15.037308  14.470000  9.242692  13.778077  10.884615
# ...               ...        ...        ...       ...        ...        ...
# 1978-5       8.270645   7.226774   6.901613  3.740645   6.973871   4.449677
# 1978-6      11.386667   9.474333  10.253333  6.053000  10.395333   7.490333
# 1978-7      12.820000   9.750968   9.910323  6.483871  10.055161   7.820645
# 1978-8       9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-9      10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
#
# ...

# %% [markdown]
# ### Step 16. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
datanew1['Week']=datanew1.index.week
datanew1.head()
# Out:
# 0             RPT    VAL    ROS   KIL    SHA   BIR    DUB   CLA    MUL    CLO  \
# Date
# 1961-01-04  10.58   6.63  11.75  4.58   4.54  2.88   8.63  1.79   5.83   5.88
# 1961-01-05  13.33  13.25  11.42  6.17  10.71  8.21  11.92  6.54  10.92  10.34
# 1961-01-06  13.21   8.12   9.96  6.67   5.37  4.50  10.67  4.42   7.17   7.50
# 1961-01-07  13.50  14.29   9.50  4.96  12.29  8.33   9.17  9.29   7.58   7.96
# 1961-01-08  10.96   9.75   7.62  5.91   9.62  7.29  14.29  7.62   9.25  10.46
#
# 0             BEL    MAL  Month  Year Month_str Year_str Year-Month  Week
# Date
# 1961-01-04   5.46  10.88      1  1961         1     1961     1961-1     1
# 1961-01-05  12.92  11.83      1  1961         1     1961     1961-1     1
# 1961-01-06   8.12  13.17      1  1961         1     1961     1961-1     1
# 1961-01-07  13.96  13.79      1  1961         1     1961     1961-1     1
# 1961-01-08  16.62  16.46      1  1961         1     1961     1961-1     1

# %%
datanew2=datanew1.query('Year==1961')

# %%
datanew2.groupby('Week').min()
# Out:
# 0       RPT    VAL    ROS   KIL    SHA   BIR    DUB   CLA    MUL    CLO  \
# Week
# 1     10.58   6.63   7.62  4.58   4.54  2.88   8.63  1.79   5.83   5.88
# 2      9.04   3.54   7.08  0.67   2.29  0.96   2.50  0.58   0.50   2.67
# 3      4.92   3.42   7.29  1.04   3.67  3.17   3.17  2.79   1.92   2.71
# 4     13.62   9.96  12.67  6.04  10.00  9.42   9.25  8.71   7.12  11.04
# 5     10.58   9.46   9.04  5.09   9.87  5.83   8.50  3.63   6.34   5.50
# 6     16.00  11.54  13.67  8.38   8.12  8.08  11.08  9.71  10.37  12.25
# 7      6.04  11.63   6.13  4.21   9.87  6.92   3.42  7.41   8.17   9.21
# 8      7.79   7.08   6.08  2.21   5.96  4.33   3.75  4.67   4.50   7.00
# 9     10.96   8.83   8.17  5.88   8.25  6.00   5.50  5.66   6.25   9.79
# 10     4.88   8.08   7.54  3.13   5.41  4.08   1.71  5.29   5.21   5.09
# 11     4.92   9.46   5.25  4.29   6.83  5.79   2.75  5.13   6.00   7.29
# 12     6.29   2.58   4.79  4.42   5.13  4.29   8.00  4.92   8.00   8.33
# ...

# %%
datanew2.groupby('Week').max()
# Out:
# 0       RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
